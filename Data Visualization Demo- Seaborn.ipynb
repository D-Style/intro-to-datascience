# %% [markdown]
# # データの読み込みと前処理

# %%
from neiss_data import load_neiss
data = load_neiss()

# %% [markdown]
# # Seaborn

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16,6)
sns.barplot(data=data, y='product', x='incident_count', estimator=sum)

# %%
g = sns.barplot(data=data, y='product', x='incident_count', estimator=sum, hue="sex")
g.figure.autofmt_xdate()

# %%
table = data.pivot_table(index='body_part', columns='product', 
                         values='incident_count', aggfunc=sum, fill_value=0)
sns.heatmap(table, cmap='Greens')

# %%
sns.boxplot(data=data, y='product', x='age')

# %%
sns.jointplot(data=data, x='day', y='age', kind='hex')
