# %% [markdown]
# # データの読み込みと前処理

# %%
from neiss_data import load_neiss
data = load_neiss()

# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.__version__
# Out:
# '2.1.1'

# %%
# Default figure size
plt.rcParams['figure.figsize'] = (16,6)

# %%
counts = data.groupby('product')['incident_count'].aggregate(sum).sort_values()

#with plt.style.context('classic'):
plt.barh(y=list(range(len(counts))), 
         width=counts,
         tick_label=counts.index)
# Out:
# <Container object of 12 artists>

# %%
counts = data.groupby('body_part')['incident_count'].aggregate(sum).sort_values()

#with plt.style.context('classic'):
plt.barh(y=list(range(len(counts))), 
         width=counts,
         tick_label=counts.index)
# Out:
# <Container object of 26 artists>

# %%
counts = data.groupby('sex')['incident_count'].aggregate(sum).sort_values()

#with plt.style.context('classic'):
plt.barh(y=list(range(len(counts))), 
         width=counts,
         tick_label=counts.index)
# Out:
# <Container object of 3 artists>
